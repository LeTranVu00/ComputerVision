# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
img = cv2.imread("cat.png")
img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.figure(figsize=(4,4))
plt.imshow(img)
plt.title("Ảnh gốc")
plt.axis("off")
plt.show()

# %%
# 3x3 là kích thước kernel, phải là số lẻ (ví dụ: 3, 5, 7), kernel càng lớn thì ảnh càng mờ
gaussian_3x3 = cv2.GaussianBlur(img, (3, 3), sigmaX=0)

plt.figure(figsize=(4,4))
plt.imshow(gaussian_3x3)
plt.title("Gaussian 3×3")
plt.axis("off")
plt.show()

# %%
gaussian_5x5 = cv2.GaussianBlur(img, (5, 5), sigmaX=0)

plt.figure(figsize=(4,4))
plt.imshow(gaussian_5x5)
plt.title("Gaussian 5×5")
plt.axis("off")
plt.show()

# %%
mean_5x5 = cv2.blur(img, (5, 5))

plt.figure(figsize=(12,4))

plt.subplot(1,3,1)
plt.imshow(img)
plt.title("Gốc")
plt.axis("off")

plt.subplot(1,3,2)
plt.imshow(gaussian_3x3)
plt.title("Gaussian 3×3")
plt.axis("off")

plt.subplot(1,3,3)
plt.imshow(gaussian_5x5)
plt.title("Gaussian 5×5")
plt.axis("off")

plt.show()
