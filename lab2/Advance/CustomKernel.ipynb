# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

img = cv2.imread("cat.png")
if img is None:
    raise FileNotFoundError("Không tìm thấy ảnh cat.png")

img = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

plt.imshow(img)
plt.title("Ảnh gốc")
plt.axis("off")
plt.show()

# %%
kernel_blur = np.ones((3,3), dtype=np.float32) / 9
blur_custom = cv2.filter2D(img, -1, kernel_blur)

plt.imshow(blur_custom)
plt.title("Kernel tự thiết kế – Làm mờ")
plt.axis("off")
plt.show()

# %%
kernel_sharpen = np.array([
    [0, -1, 0],
    [-1, 5, -1],
    [0, -1, 0]
])

sharpen_custom = cv2.filter2D(img, -1, kernel_sharpen)

plt.imshow(sharpen_custom)
plt.title("Kernel tự thiết kế – Sắc nét")
plt.axis("off")
plt.show()

# %%
kernel_edge = np.array([
    [-1, -1, -1],
    [-1,  8, -1],
    [-1, -1, -1]
])

edge_custom = cv2.filter2D(img, -1, kernel_edge)

plt.imshow(edge_custom)
plt.title("Kernel tự thiết kế – Phát hiện cạnh")
plt.axis("off")
plt.show()

# %%
kernel_emboss = np.array([
    [-2, -1, 0],
    [-1,  1, 1],
    [ 0,  1, 2]
])

emboss = cv2.filter2D(img, -1, kernel_emboss)

plt.imshow(emboss)
plt.title("Kernel tự thiết kế – Emboss")
plt.axis("off")
plt.show()

# %%
plt.figure(figsize=(12,6))

titles = ["Gốc", "Blur", "Sharpen", "Edge", "Emboss"]
images = [img, blur_custom, sharpen_custom, edge_custom, emboss]

for i in range(len(images)):
    plt.subplot(2,3,i+1)
    plt.imshow(images[i])
    plt.title(titles[i])
    plt.axis("off")

plt.show()
